# %% [markdown]
# # Step 1: Import Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_curve, roc_auc_score
print("Libraries will be uploaded successfully")
# Out:
# Libraries will be uploaded successfully

# %% [markdown]
# # Step 2: Load Dataset

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in C:\Users\Abdul\anaconda3\envs\DeveloperHub\Lib\site-packages (2.0.0)
# Requirement already satisfied: bleach in C:\Users\Abdul\anaconda3\envs\DeveloperHub\Lib\site-packages (from kaggle) (6.3.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.15 in C:\Users\Abdul\anaconda3\envs\DeveloperHub\Lib\site-packages (from kaggle) (0.1.16)
# Requirement already satisfied: packaging in C:\Users\Abdul\anaconda3\envs\DeveloperHub\Lib\site-packages (from kaggle) (25.0)
# Requirement already satisfied: protobuf in C:\Users\Abdul\anaconda3\envs\DeveloperHub\Lib\site-packages (from kaggle) (7.34.1)
# Requirement already satisfied: python-dateutil in C:\Users\Abdul\anaconda3\envs\DeveloperHub\Lib\site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in C:\Users\Abdul\anaconda3\envs\DeveloperHub\Lib\site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in C:\Users\Abdul\anaconda3\envs\DeveloperHub\Lib\site-packages (from kaggle) (2.32.5)
# Requirement already satisfied: tqdm in C:\Users\Abdul\anaconda3\envs\DeveloperHub\Lib\site-packages (from kaggle) (4.67.3)
# Requirement already satisfied: urllib3>=1.15.1 in C:\Users\Abdul\anaconda3\envs\DeveloperHub\Lib\site-packages (from kaggle) (2.6.3)
# Requirement already satisfied: webencodings in C:\Users\Abdul\anaconda3\envs\DeveloperHub\Lib\site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: six>=1.5 in C:\Users\Abdul\anaconda3\envs\DeveloperHub\Lib\site-packages (from python-dateutil->kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode>=1.3 in C:\Users\Abdul\anaconda3\envs\DeveloperHub\Lib\site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Abdul\anaconda3\envs\DeveloperHub\Lib\site-packages (from requests->kaggle) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\Abdul\anaconda3\envs\DeveloperHub\Lib\site-packages (from requests->kaggle) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\Abdul\anaconda3\envs\DeveloperHub\Lib\site-packages (from requests->kaggle) (2026.2.25)
# Requirement already satisfied: colorama in C:\Users\Abdul\anaconda3\envs\DeveloperHub\Lib\site-packages (from tqdm->kaggle) (0.4.6)

# %%
# Out:
# A subdirectory or file .kaggle already exists.
